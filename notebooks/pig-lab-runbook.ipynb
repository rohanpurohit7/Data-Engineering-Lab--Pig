# %% [markdown]
# # Apache Pig Lab Runbook
#
# Notebook-style companion for the original lab document.
#
# **Source document:** `Rohan Purohit Pig Lab.docx`
#
# The original Word document remains preserved in the repository. This notebook is an added portfolio guide, not a replacement.

# %% [markdown]
# ## Objective
#
# Present the Apache Pig lab in a clean runbook format: setup, data load, inspection, transformation, results, evidence, validation, and future improvements.

# %% [markdown]
# ## Source Document Note
#
# The repository contains the original document `Rohan Purohit Pig Lab.docx`. The available connector confirms the file exists and can retrieve it as a Word document, but it does not expose embedded text and screenshots as editable notebook cells.
#
# This notebook provides the structured runbook companion and marks where exact commands and screenshots from the Word document should be added after local review.

# %% [markdown]
# ## Conceptual Flow
#
# ```text
# Source Data -> LOAD -> Transform -> Group / Join -> Aggregate -> STORE -> Validate
# ```

# %% [markdown]
# ## Prerequisites
#
# - Apache Pig lab environment
# - Hadoop-compatible or local execution mode
# - Input dataset from the lab
# - Original Word document for exact commands and screenshot sequence

# %% [markdown]
# ## Step 1 — Environment Setup
#
# Confirm the lab environment is ready. Add the exact command and screenshot from the source document here.

# %%
# Add exact setup command from the original lab document here

# %% [markdown]
# ## Step 2 — Load Data
#
# Load the input dataset using the schema and path shown in the original document.

# %%
-- Add exact LOAD command from the original lab document here

# %% [markdown]
# ## Step 3 — Inspect Data
#
# Validate that the data loaded correctly before transformation.

# %%
-- Add exact DESCRIBE, DUMP, or ILLUSTRATE command from the original lab document here

# %% [markdown]
# ## Step 4 — Transform Data
#
# Apply the filtering, grouping, joining, or transformation logic from the lab.

# %%
-- Add exact transformation commands from the original lab document here

# %% [markdown]
# ## Step 5 — Generate Results
#
# Produce the final output expected by the lab.

# %%
-- Add exact result-generation command from the original lab document here

# %% [markdown]
# ## Step 6 — Store Output
#
# Save or display the result as described in the original lab.

# %%
-- Add exact STORE or output command from the original lab document here

# %% [markdown]
# ## Screenshot Evidence
#
# Add redacted screenshots in a `screenshots/` folder and reference them in the matching step.
#
# Suggested names:
#
# ```text
# screenshots/pig-01-setup-redacted.png
# screenshots/pig-02-load-redacted.png
# screenshots/pig-03-transform-redacted.png
# screenshots/pig-04-results-redacted.png
# ```

# %% [markdown]
# ## Validation Checklist
#
# - Confirm source data loads successfully.
# - Confirm schema assumptions match the lab.
# - Check intermediate output before final results.
# - Compare final output with the expected result.
# - Redact screenshots before publishing.

# %% [markdown]
# ## Troubleshooting
#
# - Check command syntax.
# - Check input and output paths.
# - Check delimiter and schema assumptions.
# - Remove old output folders before rerunning commands when needed.

# %% [markdown]
# ## Future State
#
# - Transcribe exact commands from the Word document.
# - Add the redacted screenshots in sequence.
# - Add a small synthetic dataset for reproducibility.
# - Add expected output examples.
# - Add documentation quality checks.
