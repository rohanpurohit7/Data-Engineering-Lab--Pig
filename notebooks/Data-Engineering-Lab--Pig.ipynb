# %% [markdown]
# # Apache Pig on Hadoop — Lab Runbook
#
# > Notebook-style runbook reconstructed from the original lab document. Original document remains preserved in the repository.

# %% [markdown]
# Apache Pig on Hadoop distributed

# %% [markdown]
# Downloaded and performed chown on pig home directory.

# %% [markdown]
# ### Evidence 1
# ![Lab evidence](attachment:evidence-1.jpg)

# %% [markdown]
# Made changes to .bashrc file to include pig home, Hadoop conf dir and pig path and classpath

# %% [markdown]
# ### Evidence 2
# ![Lab evidence](attachment:evidence-2.jpg)

# %% [markdown]
# Copied tar file from tutorial directory and untarred it to create pigtmp directory

# %% [markdown]
# ### Evidence 3
# ![Lab evidence](attachment:evidence-3.jpg)

# %% [markdown]
# Started dfs.sh

# %% [markdown]
# ### Evidence 4
# ![Lab evidence](attachment:evidence-4.jpg)

# %% [markdown]
# Started yarn.sh

# %% [markdown]
# ### Evidence 5
# ![Lab evidence](attachment:evidence-5.jpg)

# %% [markdown]
# Started job history server

# %% [markdown]
# ### Evidence 6
# ![Lab evidence](attachment:evidence-6.jpg)

# %%
JPS snapshot

# %% [markdown]
# ### Evidence 7
# ![Lab evidence](attachment:evidence-7.jpg)

# %%
Pig Script 1: Query Phrase Popularity

# %% [markdown]
# The Query Phrase Popularity script (script1-local.pig or script1-hadoop.pig) processes a search query log file from the Excite search engine and finds search phrases that occur with particular high frequency during certain times of the day.

# %% [markdown]
# Ran script1 file in pigtmp directory using pig command

# %% [markdown]
# ### Evidence 8
# ![Lab evidence](attachment:evidence-8.jpg)

# %% [markdown]
# ### Evidence 9
# ![Lab evidence](attachment:evidence-9.jpg)

# %% [markdown]
# Succesfully wrote output file to /user/Hadoop/script1-hadoop-results

# %% [markdown]
# ### Evidence 10
# ![Lab evidence](attachment:evidence-10.jpg)

# %% [markdown]
# ### Evidence 11
# ![Lab evidence](attachment:evidence-11.jpg)

# %%
Pig Script 2: Temporal query phrase popularity

# %% [markdown]
# The Temporal Query Phrase Popularity script (script2-local.pig or script2-hadoop.pig) processes a search query log file from the Excite search engine and compares the occurrence of frequency of search phrases across two time periods separated by twelve hours.

# %% [markdown]
# Ran script2 in pigtmp

# %% [markdown]
# ### Evidence 12
# ![Lab evidence](attachment:evidence-12.jpg)

# %% [markdown]
# ### Evidence 13
# ![Lab evidence](attachment:evidence-13.jpg)

# %% [markdown]
# ### Evidence 14
# ![Lab evidence](attachment:evidence-14.jpg)

# %% [markdown]
# ### Evidence 15
# ![Lab evidence](attachment:evidence-15.jpg)

# %% [markdown]
# Searched Hadoop fs for script results

# %% [markdown]
# ### Evidence 16
# ![Lab evidence](attachment:evidence-16.jpg)

# %% [markdown]
# Detailed results file from pigscript2-temporal query

# %% [markdown]
# ### Evidence 17
# ![Lab evidence](attachment:evidence-17.jpg)

# %% [markdown]
# ## Modernization Notes
#
# This notebook preserves the historical lab sequence. Before rerunning, validate versions, package repositories, service commands, client shells, and platform-specific paths against current vendor documentation.
